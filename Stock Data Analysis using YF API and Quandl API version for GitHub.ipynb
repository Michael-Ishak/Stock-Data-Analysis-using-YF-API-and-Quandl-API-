# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from requests.auth import HTTPBasicAuth
from datetime import date
from datetime import date
# %matplotlib inline

current = date.today() # creating integer value for current year
current_date = current.strftime("%Y-%m-%d")
current_date
# Out:
# '2022-09-06'

# %%
import yfinance as yf # import yahoo finance

start_date = '1990-01-01' # set start date

ticker = 'NVDA' # stock ticker

stock_data = yf.download(ticker, start_date, current_date) # grab the data


stock_data.tail(10) # print last 10 rows
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-08-22  174.899994  175.580002  169.660004  170.339996  170.339996
# 2022-08-23  169.889999  174.649994  169.699997  171.809998  171.809998
# 2022-08-24  170.119995  174.059998  168.949997  172.220001  172.220001
# 2022-08-25  168.440002  179.470001  168.330002  179.130005  179.130005
# 2022-08-26  178.570007  179.240005  162.369995  162.600006  162.600006
# 2022-08-29  160.199997  163.380005  157.669998  158.009995  158.009995
# 2022-08-30  159.600006  160.389999  151.820007  154.679993  154.679993
# 2022-08-31  153.839996  155.399994  149.589996  150.940002  150.940002
# 2022-09-01  142.089996  143.800003  132.699997  139.369995  139.369995
# 2022-09-02  141.000000  141.710007  135.910004  136.470001  136.470001
#
#                  Volume
# Date
# 2022-08-22   40959300.0
# 2022-08-23   36998600.0
# 2022-08-24   52266100.0
# ...

# %%
stockdata = pd.read_html("https://en.wikipedia.org/wiki/List_of_S%26P_500_companies")[0]
print(stockdata.head())
# Out:
#   Symbol     Security SEC filings  GICS Sector         GICS Sub-Industry  \
# 0    MMM           3M     reports  Industrials  Industrial Conglomerates
# 1    AOS  A. O. Smith     reports  Industrials         Building Products
# 2    ABT       Abbott     reports  Health Care     Health Care Equipment
# 3   ABBV       AbbVie     reports  Health Care           Pharmaceuticals
# 4   ABMD      Abiomed     reports  Health Care     Health Care Equipment
#
#      Headquarters Location Date first added      CIK      Founded
# 0    Saint Paul, Minnesota       1976-08-09    66740         1902
# 1     Milwaukee, Wisconsin       2017-07-26    91142         1916
# 2  North Chicago, Illinois       1964-03-31     1800         1888
# 3  North Chicago, Illinois       2012-12-31  1551152  2013 (1888)
# 4   Danvers, Massachusetts       2018-05-31   815094         1981

# %%
intraday_data = yf.download(tickers="NVDA", period="5d", interval="1m", auto_adjust=True)
intraday_data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2022-08-29 09:30:00-04:00  161.500000  161.699997  161.300003  161.339996
# 2022-08-29 09:31:00-04:00  161.367599  161.929901  161.300003  161.869995
# 2022-08-29 09:32:00-04:00  162.009995  162.219894  161.770004  162.130005
# 2022-08-29 09:33:00-04:00  162.130005  162.449997  161.651703  162.419998
# 2022-08-29 09:34:00-04:00  162.389999  162.600006  162.180099  162.369995
#
#                             Volume
# Datetime
# 2022-08-29 09:30:00-04:00  1696139
# 2022-08-29 09:31:00-04:00   174981
# 2022-08-29 09:32:00-04:00   478512
# 2022-08-29 09:33:00-04:00   273318
# 2022-08-29 09:34:00-04:00   313085

# %%
import quandl

# %%
Quandl_API_Key = 'XXXXXXXXXXX'
if Quandl_API_Key != "XXXXXXXXX":
    raise Exception("Provide a valid API key.")

# %%
start_date = '1990-01-01'
end_date = current_date
ticker = 'NVDA'

# Grabbing the data
data = quandl.get('WIKI/'+ticker, start_date=start_date, end_date=end_date, api_key=Quandl_API_Key)
data.head(10)
# Out:
#              Open   High    Low  Close     Volume  Ex-Dividend  Split Ratio  \
# Date
# 1999-01-22  21.00  23.44  18.63  19.69  5655600.0          0.0          1.0
# 1999-01-25  21.25  22.00  19.69  21.75  1063500.0          0.0          1.0
# 1999-01-26  22.00  22.44  19.75  20.06   715000.0          0.0          1.0
# 1999-01-27  20.13  20.63  19.00  20.00   509100.0          0.0          1.0
# 1999-01-28  20.00  20.13  19.81  19.94   474000.0          0.0          1.0
# 1999-01-29  19.94  20.00  19.00  19.00   508400.0          0.0          1.0
# 1999-02-01  19.00  19.50  19.00  19.38   322300.0          0.0          1.0
# 1999-02-02  19.00  19.50  17.31  17.88   550200.0          0.0          1.0
# 1999-02-03  17.63  18.50  17.50  18.25   156500.0          0.0          1.0
# 1999-02-04  18.50  19.75  18.25  19.25   379000.0          0.0          1.0
#
#             Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# Date
# ...

# %% [markdown]
# # Grabbing the basic data

# %%
Nvidia = yf.Ticker("NVDA")
Nvidia
#msft = yf.download('MSFT', start_date, end_date)
msft = yf.Ticker("MSFT")

# %% [markdown]
# ## NVIDIA Revenue, Gross Profit and Statements

# %%
revenue = Nvidia.financials.loc['Total Revenue']
a = pd.DataFrame(data = values, index=indexing)
print(a[0])
indexing = list(revenue.index)
values = np.array(list(revenue))
plt.plot(a[0])
plt.ylabel("Total Revenue in $(1x10^10)")
plt.xlabel("Timeframe")
plt.title('Total Revenue')
plt.xlim([indexing[-1], indexing[0]])

plt.show()
# Out:
# 2022-01-30    2.691400e+10
# 2021-01-31    1.667500e+10
# 2020-01-26    1.091800e+10
# 2019-01-27    1.171600e+10
# Name: 0, dtype: float64

# %%
GProfit = Nvidia.financials.loc['Gross Profit']
a = pd.DataFrame(data = values, index=indexing)
print(a[0])
indexing = list(GProfit.index)
values = np.array(list(GProfit))
plt.plot(a[0])
plt.ylabel("Gross Profit in $(1x10^10)")
plt.xlabel("Timeframe")
plt.title('Gross Profit')
plt.xlim([indexing[-1], indexing[0]])

plt.show()
# Out:
# 2022-01-30    2.691400e+10
# 2021-01-31    1.667500e+10
# 2020-01-26    1.091800e+10
# 2019-01-27    1.171600e+10
# Name: 0, dtype: float64

# %%
Nvidia.financials # income statement

Nvidia.balance_sheet # balance sheet

Nvidia.cashflow # cashflow statement

Nvidia.info # other relevant information
# Out:
# {'zip': '95051',
#  'sector': 'Technology',
#  'fullTimeEmployees': 22473,
# ...

# %% [markdown]
# # Stock Market Data Visualization

# %%
import pyfolio as pf

# %%
tickers = ['NVDA', 'AAPL', 'AMZN', 'MSFT']
data = pd.DataFrame(columns=tickers)
for i in tickers:
     data[i] = yf.download(i, period='5y',)['Adj Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
data = data.pct_change().dropna().mean(axis=1) # Daily mean returns for using stocks in 'tickers'
pf.create_simple_tear_sheet(data) # Creates a dashboard of sorts with cumulative returns, ratios and drawdown plots
# Out:
# C:\Users\ishak\anaconda3\lib\site-packages\pyfolio\timeseries.py:724: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   stats = pd.Series()
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2017-09-06</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-09-02</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>59</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>30.2%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>272.9%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>32.0%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.98</td>
# ...
